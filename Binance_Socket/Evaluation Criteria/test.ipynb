# %%
import pymongo
import pandas as pd
from datetime import datetime
import numpy as np
import requests
import re
import ast
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler


def EvaluationCriteria(Coin,Targets,timestamp):
    valList = []
    durationList = []
    x = requests.get(f'https://api.binance.com/api/v3/klines?symbol={Coin}&interval=30m&startTime={timestamp}&limit=1000')
    df = pd.DataFrame(ast.literal_eval(x.content.decode())).iloc[:,[0,2]]
    # P = 0
    # t1achieved,t2achieved,t3achieved = False,False,False
    # for index,i in enumerate(Targets): 
    #     L = df[df.iloc[:,1].apply(lambda x: float(x)) >= i].index.to_list()
    #     if len(L) != 0:
    #         L=L[0]+1
    #         durationList.append(df.iloc[L,0])
    #         valList.append(df.iloc[P:L,1].to_list())
    #         P=L
    #     else:
    #          durationList.append(None)
    #          valList.append(None)

    # secList = [i for i in range(16,0,-1)]
    # secList = np.reshape(secList, (-1,1))
    # minMaxScaler = MinMaxScaler(feature_range=(0, 1))
    # minMaxScaler.fit(secList)
    # scaledList1 = minMaxScaler.transform(secList)

    # f1 = scaledList1[int(round(durationList[0],0))][0]
    # f2 = scaledList1[int(round(durationList[1],0))][0]
    # f3 = scaledList1[int(round(durationList[1],0))][0]

    # print("timeframe:",f1,f2,f3)

    # q1,q2,q3 =[ np.std(i)/(np.std(valList[0])+np.std(valList[1])+np.std(valList[2])) for i in valList]

    # print("quantile->",q1,q2,q3)

    # a = np.array([0.2*q1,0.8*f1])
    # b = np.array([0.2*q2,0.8*f2])
    # c = np.array([0.2*q3,0.8*f3])

    # if (t1achieved and t2achieved and t3achieved and not stoplossachieved):
    #     w1 = np.sum(a)
    #     w2 = np.sum(b)
    #     w3 = np.sum(c)
    #     # w1=f1
    #     # w2=f2
    #     # w3=f3

    # elif (t1achieved and not stoplossachieved):
    #     maxVal = max(valList1)
    #     target = [T1,T2,T3]
    #     w1 = np.sum(a)
    #     # w1 = f1
        
    #     rangedWeightage = 0
    #     if maxVal>min(target):
    #         per = (maxVal/[i for i in target if i>maxVal][0])
    #         rangedWeightage = 0.1 + (math.pow(per, 5)) * (0.4 - 0.1)
        
    #     if (not t2achieved and not t3achieved):
    #         w2 = rangedWeightage
    #         w3 = 0
    #     elif(not t3achieved):
    #         w3 = rangedWeightage
    #         w2 = np.sum(b)
    #         # w2 = f2
    # elif(not t1achieved and not t2achieved and not t3achieved):
    #     maxVal = max(valList1,valList2,valList3)
    #     target = [T1,T2,T3]
    #     rangedWeightage = 0
    #     if maxVal>min(target):
    #         per = (maxVal/[i for i in target if i>maxVal][0])
    #         rangedWeightage = 0.1 + (math.pow(per, 5)) * (0.2 - 0.1)
    #     w1 = rangedWeightage
    #     w2=0
    #     w3=0
    # elif(not t1achieved and not t2achieved and not t3achieved
    #     and stoplossachieved):
    #     w1 = 0
    #     w2 = 0
    #     w3 = 0
    # elif (t1achieved and not t2achieved and stoplossachieved):
    #     w1 = np.sum(a)
    #     # w1 = f1
    #     w2 = 0
    #     w3 = 0
    #     sl = stoplossvalue/CurrentValue

    # elif(t1achieved and t2achieved and not t3achieved and stoplossachieved):
    #     w1 = np.sum(a)
    #     w2 = np.sum(b)
    #     # w1 = f1
    #     # w2 = f2
    #     w3=0
    #     sl = stoplossvalue/CurrentValue


    # p1 = ((T1 - CurrentValue) / CurrentValue)
    # p2 = ((T2 - T1) / T1)
    # p3 = ((T3 - T2) / T2)

    # print("percentage->",p1,p2,p3)
    # # sl = ((value-stoploss)/stoploss)
    # if (not stoplossachieved):
    #     x = ((p1*w1) + (p2*w2) + (p3*w3)) / (p1+p2+p3)
    # else:
    #     x = ((p1*w1) + (p2*w2) + (p3*w3))/(p1+p2+p3+sl)

    # print("Evaluation Value: ",x*100)


x = requests.get(f'https://api.binance.com/api/v3/ticker/24hr')
x = ast.literal_eval(x.content.decode())
client = pymongo.MongoClient(
    "mongodb+srv://admin:BSfzY7TU5FjPkvO7@cluster0.hqyhi3g.mongodb.net/test")
db = client.Twigram
cursor = db.Telegram.find({})
for document in cursor:
    if(document['Call']['Status']=="A"):
        for coins in x:
            if re.search(document['Call']['Coin']+document['Call']['Conversion'],coins['symbol']):
            # print(document['Call']['Coin'],coins['symbol'])
            # Evaluation Criteria Function Only to be run if 30 days have been passed
            # Parameters of Evaluation Criteria Targets ,valList , durationList 
            # Change Timestamp in original File
                EvaluationCriteria(document['Call']['Coin']+document['Call']['Conversion'],document['Call']['Targets'],str(int(datetime.timestamp(datetime.strptime((document['Date']+" "+document['Time']), '%Y-%m-%d %H:%M:%S')))).ljust(13, '0'))
# Out:
# [['0.42790000', '0.42920000', '0.43210000', '0.43480000', '0.43570000', '0.43700000', '0.43970000', '0.45270000', '0.45300000', '0.45080000', '0.46630000', '0.45900000', '0.45570000', '0.45770000', '0.46510000', '0.47260000', '0.46900000', '0.46850000', '0.46770000', '0.46120000', '0.45940000', '0.45930000', '0.45810000', '0.45110000', '0.44880000', '0.44840000', '0.45180000', '0.45030000', '0.45590000', '0.45350000', '0.45210000', '0.45690000', '0.47940000', '0.48830000'], None, None, None]
# ...
