# %%
import pandas as pd
import re
from csv import writer

# %%
colnames=['Name','Date','Time', 'Text','Cleaned_text'] 
exchanges = ['BINANCE', 'BYBIT', 'FTX', 'HUOBI', 'KUCOIN', 'POLONIEX','KRAKEN']
df = pd.read_csv('./1_The_CryptoLogy_Signals.csv',names = colnames,header=None)
print(df['Cleaned_text'][0])
print(df['Text'][0])
df.head()
# Out:
# ['📌', 'ODIN', 'PLATFORM', '-', 'For', 'trader', 'mentor', 'algo-trading🌍', 'Website', 'odinplatform.io🔑', 'MVP', 'odinplatform.com⚡️', 'Status', '90', 'Developed\U0001fa99', 'Exchange', 'PancakeSwap📈', 'Contract', '0x42f7332b14347c9F77A9bef1aC7bB60d2cd9Ec2e---------📌', 'What', 'ODIN', 'Platform', 'The', 'Odin', 'platform', 'serve', 'one-stop-shop', 'anything', 'related', 'cryptocurrencies.', 'Educational', 'material', 'monetization', 'copy', 'trading', 'self-hosted', 'environment', 'algorithmic', 'trading', 'much', 'provide', 'trader', 'investor', 'rich', 'feature', 'environment', 'needs.', '⚡️', 'Odin', 'Highlights-', 'Odin', 'ODN', 'recently', 'listed', 'PancakeSwap', 'bullish', 'opening', 'day', 'price', 'increasing', '200-', 'Strong', 'project', 'fundamentals.', 'Expanding', 'token', 'case', 'use.-', 'Potential', '200x', 'return', 'project', 'get', 'listed', 'exchanges.👉', 'Trading', 'on', 'Pancakeswap💥Contract', '0x42f7332b14347c9F77A9bef1aC7bB60d2cd9Ec2e🌍', 'httpsodinplatform.io...']
# 📌 ODIN PLATFORM - For traders, mentors and algo-trading🌍 Website: odinplatform.io🔑 MVP: odinplatform.com⚡️ Status: 90% Developed🪙 Exchange: PancakeSwap📈 Contract: 0x42f7332b14347c9F77A9bef1aC7bB60d2cd9Ec2e---------📌 What is the ODIN Platform? The Odin platform will serve as a one-stop-shop for anything related to cryptocurrencies. Educational material, monetization, copy trading, a self-hosted environment for algorithmic trading, and much more to provide traders & investors with a rich feature environment for all their needs.  ⚡️ Odin Highlights- Odin (ODN), which was recently listed on PancakeSwap, has had a very bullish opening day, with the price increasing by over 200%- Strong project fundamentals. Expanding token case use.- Potential 200x returns as the project gets listed on more exchanges.👉 Trading on: Pancakeswap💥Contract: 0x42f7332b14347c9F77A9bef1aC7bB60d2cd9Ec2e🌍 https://odinplatform.io/...
#                      Name        Date      Time  \
# 0  The_CryptoLogy_Signals  2022-05-23  15:20:21
# 1  The_CryptoLogy_Signals  2022-09-22  19:04:06
# 2  The_CryptoLogy_Signals  2022-10-03  07:05:01
# 3  The_CryptoLogy_Signals  2022-10-03  07:05:19
# 4  The_CryptoLogy_Signals  2022-10-03  07:54:54
#
#                                                 Text  \
# 0  📌 ODIN PLATFORM - For traders, mentors and alg...
# 1  🚨🚨 *AMAZING NEWS*  🚨🚨✴️ Leading fan token plat...
# 2  COIN NAME:#DOT/USDTDirections: Long🚀Entry: $6....
# 3  COIN NAME:#HBAR/USDTDirections: Long🚀Entry: $0...
# 4  COIN NAME:#ADA/USDTDirections: Long🚀#ADA rejec...
#
#                                         Cleaned_text
# 0  ['📌', 'ODIN', 'PLATFORM', '-', 'For', 'trader'...
# 1  ['🚨🚨', 'AMAZING', 'NEWS', '🚨🚨✴️', 'Leading', '...
# 2  ['COIN', 'NAMEDOTUSDTDirections', 'Long🚀Entry'...
# 3  ['COIN', 'NAMEHBARUSDTDirections', 'Long🚀Entry...
# 4  ['COIN', 'NAMEADAUSDTDirections', 'Long🚀ADA', ...

# %%
exchanges = 'Binance|kucoin|bitbuy'
conversion = 'usdt|usd|btc|eth'
exchangeregex = '|'.join(exchanges)
target = ('|').join(['1','2','3'])
# coins=''
def extractor(i):
  text = re.sub('[\',\[\]]', '', i)

  if(re.search('usdt|usd|btc|eth',text,re.IGNORECASE) and re.search('target|targets',text,re.IGNORECASE)):    

    coin_name=re.findall('(\w+)\s*(?:usdt|usd|btc|eth)',text,re.IGNORECASE)
    if coin_name: coin_name=coin_name[0]

    conversion_name = re.findall('\w+\s*({})'.format(conversion),str(text),re.IGNORECASE)
    if conversion_name: conversion_name = conversion_name[0]

    """exchange not used"""
    call_exchange = re.findall('\w+({})'.format(exchanges),text,re.IGNORECASE)

    """call_type not used"""
    call_type = re.findall('sell|buy',text,re.IGNORECASE)

    call_duration = re.findall('long|short',text,re.IGNORECASE)
    if call_duration: call_duration = call_duration[0]    
    
    # targets = re.findall(r'target[s]*\s*✅*🎯*\s*\d.\d*\s*',text,re.IGNORECASE)
    """some targets are not extracted although format is same """
    T={}
    # targets=re.findall(r'target\s*[ ]*\s*(\d.\d*)s*[ ]*\s*(\d.\d*)s*[ ]*\s*(\d.\d*)s*[ ]*\s*(\d.\d*)',text,re.IGNORECASE)
    # targets = re.findall("Target[s]*[ ]*(.*?)[a-zA-Z]",text,re.IGNORECASE)
    # targets = re.sub(r"[^0-9.]"," ", targets[0], flags=re.IGNORECASE)
    print(targets)

    # if not targets: print(text,"\n")
    # print(targets)
    
    # if targets:
    #   T['T1']=targets[0][0]
    #   T['T2']=targets[0][1]
    #   T['T3']=targets[0][2]
    #   T['T4']=targets[0][3]

    leverage = re.findall('[ ]*[-]*[ ]*(\d+)x',text,re.IGNORECASE)

    """ stop loss not used that much"""
    stop_loss = re.findall('stop\s*-*\s*loss\s*-*\s*(\d.\d*)',text,re.IGNORECASE)

    # with open('./2_Dash2Trade.csv', 'a',newline='') as f_object:
    #   writer_object = writer(f_object)
    #   ls = [coin_name,conversion_name,leverage,call_exchange,call_type,call_duration,T,stop_loss]
    #   writer_object.writerow(ls)
    #   f_object.close()

  return i
  
df['Cleaned_text'].apply(extractor)
# Out:
# ['📌', 'ODIN', 'PLATFORM', '-', 'For', 'trader', 'mentor', 'algo-trading🌍', 'Website', 'odinplatform.io🔑', 'MVP', 'odinplatform.com⚡️', 'Status', '90', 'Developed\U0001fa99', 'Exchange', 'PancakeSwap📈', 'Contract', '0x42f7332b14347c9F77A9bef1aC7bB60d2cd9Ec2e---------📌', 'What', 'ODIN', 'Platform', 'The', 'Odin', 'platform', 'serve', 'one-stop-shop', 'anything', 'related', 'cryptocurrencies.', 'Educational', 'material', 'monetization', 'copy', 'trading', 'self-hosted', 'environment', 'algorithmic', 'trading', 'much', 'provide', 'trader', 'investor', 'rich', 'feature', 'environment', 'needs.', '⚡️', 'Odin', 'Highlights-', 'Odin', 'ODN', 'recently', 'listed', 'PancakeSwap', 'bullish', 'opening', 'day', 'price', 'increasing', '200-', 'Strong', 'project', 'fundamentals.', 'Expanding', 'token', 'case', 'use.-', 'Potential', '200x', 'return', 'project', 'get', 'listed', 'exchanges.👉', 'Trading', 'on', 'Pancakeswap💥Contract', '0x42f7332b14347c9F77A9bef1aC7bB60d2cd9Ec2e🌍', 'httpsodinplatform.io...']
# ['🚨🚨', 'AMAZING', 'NEWS', '🚨🚨✴️', 'Leading', 'fan', 'token', 'platform', 'Bitci.com’s', 'mainnet', 'coin', 'Bitcicoin', 'listed', 'Gate.io', 'Startup', 'Activation', '09.23.2022', 'UTC', 'Listing', 'Date', '09.23.2022', '10.00', 'AM', 'UTC⚡️⚡️', 'BİTCİCOIN', '⚡️⚡️-', 'Main', 'net', 'coin', 'Bitcichain', 'network-', 'It', 'bind', 'product', 'service', 'offered', 'Bitci', 'Ecosystem-', 'Tokens', 'project', 'running', 'Bitcichain', 'may', 'easily', 'converted', 'Bitcicoin', 'may', 'traded', 'Bitcicoin', 'Market', 'market', 'different', 'exchanges-', 'Bitcicoin', 'tradeable', 'buy', 'fan', 'token', 'Bitcicoin', 'tradeable', 'buy', 'fan', 'token', 'It', 'gonna', 'used', 'NFT', 'gaming', 'project', '-', 'Its', 'value', 'determined', 'current', 'future', 'fan', 'token', 'project', 'developed', 'Bitcichain.⚙️⚙️', 'BİTCİCHAIN', '⚙️⚙️-', 'It', 'blockchain', 'infrastructure', 'Bitci', 'Teknoloji', 'develops', 'private', 'brand', 'token', 'company', 'institutions-', 'Fan', 'token', 'sport', 'club', 'Spain', 'National', 'Football', 'Team', 'Brazil', 'National', 'Football', 'Team', 'Rangers', 'Football', 'Club', 'MOTOGP', 'McLaren', 'improved', 'Bitcichain', 'blockchain', 'network.-', 'Loyalty', 'token', 'created', 'Bitcichain', 'companies.-', 'Businesses', 'distribute', 'token', 'user', 'reward', 'discount', 'prepaid', 'personalized', 'digital', 'account', 'offered', 'Bitcichain.-', 'Bitcichain', 'offer', 'blockchain', 'based', 'smart', 'contract', 'secure', 'traceable', 'way', 'keeping', 'account', 'logistics', 'procurement👇🏻👇🏻To', 'explore', 'amazing', 'blockchain', 'company', '👇🏻👇🏻BİTCİCOIN', 'IS', 'AVAILABLE', 'ON-', 'XT', '-', 'MEXC', '-', 'LBank', '-', 'Big', 'One-', 'Probit-', 'Biconomy-', 'Finexbox-', 'Bittrex-', 'Bitget-', 'BitMartFOLLOW', 'US', 'ON', 'SOCIAL', 'MEDIATWITTER', 'bitcichain']
# ['COIN', 'NAMEDOTUSDTDirections', 'Long🚀Entry', '6.28-6.18✅Target', 'Profit', '1', '6.35Target', 'Profit', '2', '6.50Target', 'Profit', '3', '6.80Target', 'Profit', '4', '7.00', 'Target', 'Profit', '5', '7.26Stop', 'loss', '5.94']
# ['COIN', 'NAMEHBARUSDTDirections', 'Long🚀Entry', '0.0571-0.0565✅Target', 'Profit', '1', '0.0582Target', 'Profit', '2', '0.0590Target', 'Profit', '3', '0.0600Target', 'Profit', '4', '0.0620Target', 'Profit', '5', '0.0650Stop', 'loss', '0.0550']
# ['COIN', 'NAMEADAUSDTDirections', 'Long🚀ADA', 'reject', 'supportEntry', '0.4250-0.4187✅Target', 'Profit', '1', '0.4348Target', 'Profit', '2', '0.4400Target', 'Profit', '3', '0.4457Target', 'Profit', '4', '0.4600Stop', 'loss', '0.4027']
# ['These', 'coin', 'I', 'would', 'recommend', 'HODL.', 'ATOM', '✅ARPA', '✅NEAR', '✅HBAR', '✅MATIC', '✅', 'DOT✅']
# ['DOTUSDT', 'LONGLeverage', 'Cross', '50xEntry', '6.304Target', '1', '6.392Target', '2', '6.449Target', '3', '6.544Stoploss', '6.184']
# ['COIN', 'NAMEDOTUSDT', 'Directions', 'Long🚀', 'Entry', '6.28-6.18✅', 'Target', 'Profit', '1', '6.35', 'Target', 'Profit', '2', '6.50', 'Target', 'Profit', '3', '6.80', 'Target', 'Profit', '4', '7.00', 'Target', 'Profit', '5', '7.26', 'Stop', 'loss', '5.94']
# ['DOTUSDT', 'LONG', 'Leverage', 'Cross', '50x', 'Entry', '6.304', 'Target', '1', '6.392', 'Target', '2', '6.449', 'Target', '3', '6.544', 'Stoploss', '6.184']
# ['We', 'Be', 'Providing', 'Free', 'Signals', 'For', 'Week', 'Make', 'Sure', 'try', 'Signals', '📈✅From', 'Next', 'week', 'We', 'Launching', 'Our', 'Premium', 'Paid', 'Signals', 'Group', '🍻🔥']
# ['The', 'CryptoLogy', '💎', '•', 'Signals', '•', 'Alerts', '🔔', 'pinned', '«We', 'Be', 'Providing', 'Free', 'Signals', 'For', 'Week', 'Make', 'Sure', 'try', 'Signals', '📈✅', 'From', 'Next', 'week', 'We', 'Launching', 'Our', 'Premium', 'Paid', 'Signals', 'Group', '🍻🔥»']
# ['DOTUSDT', 'LONG', 'Leverage', 'Cross', '50x', 'Entry', '6.304', 'Target', '1', '6.392', 'Target', '2', '6.449', 'Target', '3', '6.544', 'Stoploss', '6.184']
# ['COIN', 'NAMEADAUSDT', 'Directions', 'Long🚀', 'ADA', 'reject', 'support', 'Entry', '0.4250-0.4187✅', 'Target', 'Profit', '1', '0.4348', 'Target', 'Profit', '2', '0.4400', 'Target', 'Profit', '3', '0.4457', 'Target', 'Profit', '4', '0.4600', 'Stop', 'loss', '0.4027']
# ['🔴', 'Short', 'KSMUSDTEntry', '43.836', '-', '44.217Targets', '🎯', '43.600🎯', '42.577🎯', '41.500🛑', 'Stop', '46.538Leverage', '10x', 'isolated']
# ['COIN', 'NAMEHBARUSDT', 'Directions', 'Long🚀', 'Entry', '0.0571-0.0565✅', 'Target', 'Profit', '1', '0.0582', 'Target', 'Profit', '2', '0.0590', 'Target', 'Profit', '3', '0.0600', 'Target', 'Profit', '4', '0.0620', 'Target', 'Profit', '5', '0.0650', 'Stop', 'loss', '0.0550']
# ['LongSFPUSDTEntry', '0.3779-', '0.3788Targets', '🎯', '0.3800🎯', '0.3815🎯', '0.3825🛑', 'Stop', '0.3541Leverage', '10x', 'isolated']
# ['COIN', 'NAMEHBARUSDT', 'Directions', 'Long🚀', 'Entry', '0.0571-0.0565✅', 'Target', 'Profit', '1', '0.0582', 'Target', 'Profit', '2', '0.0590', 'Target', 'Profit', '3', '0.0600', 'Target', 'Profit', '4', '0.0620', 'Target', 'Profit', '5', '0.0650', 'Stop', 'loss', '0.0550']
# ['Currently', 'forming', 'bullish', 'divergence', 'double', 'bottom.', 'Recent', 'Point', 'control', 'zone', 'around', 'bottom', 'volume', 'traded', 'around', 'area', 'I', 'believe', 'whale', 'buying', 'now', 'could', 'see', 'reversal', 'upside', 'soon', 'bitcoin', 'I', 'trade', 'first', 'resistance', 'look', 'risky', 'I', 'short', 'one', 'close', 'pump.', 'Then', 'go', 'grab', 'liquidity', 'going', 'upwards', 'continue', 'going', 'downwards', 'filling', 'point', 'interest', 'zone', 'recent', 'structure', 'broke.', 'First', 'TP', 'reached', 'see.If', 'fail', 'reach', 'tps', 'close', 'first', 'short', 'stop', 'loss', 'see', 'another', 'massive', 'pump', 'next', 'point', 'interest', 'zone.Bitcoin', 'Short', 'term', 'BULLISHMid-term', '65', 'Bullish']
# ['Analysis', 'Btc', 'fail', 'break', 'resistance', '20200', 'discus', 'Last', 'market', 'update', 'Hope', 'u', 'booked', 'ur', 'profit', 'The', 'market', 'still', 'volatile', 'careful', 'trade', 'safeToday', '12', 'pm', 'gmt', 'FOMC', 'member', 'giving', 'speech', 'market', 'closely', 'monitoring', 'statementsSo', 'new', 'member', 'take', 'trade', 'time.']
# ['Good', 'opportunity', 'short', 'LTCUSDT']
# ['Good', 'opportunity', 'short', 'LTCUSDT']
# ['Long', 'SFPUSDT', 'Entry', '0.3779-', '0.3788', 'Targets', '🎯', '0.3800', '🎯', '0.3815', '🎯', '0.3825', '🛑', 'Stop', '0.3541', 'Leverage', '10x', 'isolated']
# ['Long', 'SFPUSDT', 'Entry', '0.3779-', '0.3788', 'Targets', '🎯', '0.3800', '🎯', '0.3815', '🎯', '0.3825', '🛑', 'Stop', '0.3541', 'Leverage', '10x', 'isolated']
# ['🔴', 'Short', 'KSMUSDT', 'Entry', '43.836', '-', '44.217', 'Targets', '🎯', '43.600', '🎯', '42.577', '🎯', '41.500', '🛑', 'Stop', '46.538', 'Leverage', '10x', 'isolated']
# ['DOTUSDT', 'LONG', 'Leverage', 'Cross', '50x', 'Entry', '6.304', 'Target', '1', '6.392', 'Target', '2', '6.449', 'Target', '3', '6.544', 'Stoploss', '6.184']
# ['Binance🔴', 'SHORTHNTUSDTEntry', '5.2187', '-', '5.2641Targets', '🎯', '5.1914🎯', '5.0814🎯', '4.9714🛑', 'Stop', '5.5403Leverage', '10x', 'isolated']
# ['COIN', 'NAMEDOTUSDT', 'Directions', 'Long🚀', 'Entry', '6.28-6.18✅', 'Target', 'Profit', '1', '6.35', 'Target', 'Profit', '2', '6.50', 'Target', 'Profit', '3', '6.80', 'Target', 'Profit', '4', '7.00', 'Target', 'Profit', '5', '7.26', 'Stop', 'loss', '5.94']
# ['Binance🟢', 'LongHBARUSDTEntry', '5780', '-', '5795Targets', '🎯', '5825🎯', '5850🎯', '5890🎯', '5910🛑', 'Stop', '5418Leverage', '10x', 'isolated']
# ['Binance', '🔴', 'SHORT', 'HNTUSDT', 'Entry', '5.2187', '-', '5.2641', 'Targets', '🎯', '5.1914', '🎯', '5.0814', '🎯', '4.9714', '🛑', 'Stop', '5.5403', 'Leverage', '10x', 'isolated']
# ['Good', 'opportunity', 'short', 'LTCUSDT']
# ['Binance', '🟢', 'Long', 'HBARUSDT', 'Entry', '5780', '-', '5795', 'Targets', '🎯', '5825', '🎯', '5850', '🎯', '5890', '🎯', '5910', '🛑', 'Stop', '5418', 'Leverage', '10x', 'isolated']
# ['COIN', 'NAME', 'XRPUSDT', 'LongLeverage', '10x', 'Directions', 'Long', '🚀Entry', '0.4936-0.4662✅Target', 'Profit', '1', '0.4988Target', 'Profit', '2', '0.5045Target', 'Profit', '3', '0.5285Target', 'Profit', '4', '0.5531Stop', 'loss', '0.45']
# ['AVAXUSDT', 'LONGLeverage', 'Cross', '50xEntry', '17.34Target', '1', '17.51Target', '2', '17.69Target', '3', '17.98Stoploss', '17.03']
# ['COIN', 'NAME', 'XRPUSDT', 'Long', 'Leverage', '10x', 'Directions', 'Long', '🚀', 'Entry', '0.4936-0.4662✅', 'Target', 'Profit', '1', '0.4988', 'Target', 'Profit', '2', '0.5045', 'Target', 'Profit', '3', '0.5285', 'Target', 'Profit', '4', '0.5531', 'Stop', 'loss', '0.45']
# ['COIN', 'NAME', 'XRPUSDT', 'Long', 'Leverage', '10x', 'Directions', 'Long', '🚀', 'Entry', '0.4936-0.4662✅', 'Target', 'Profit', '1', '0.4988', 'Target', 'Profit', '2', '0.5045', 'Target', 'Profit', '3', '0.5285', 'Target', 'Profit', '4', '0.5531', 'Stop', 'loss', '0.45']
# ['AVAXUSDT', 'LONG', 'Leverage', 'Cross', '50x', 'Entry', '17.34', 'Target', '1', '17.51', 'Target', '2', '17.69', 'Target', '3', '17.98', 'Stoploss', '17.03']
# ['Good', 'opportunity', 'short', 'BCHUSDT']
# ['AVAXUSDT', 'SHORTLeverage', 'Cross', '50xEntry', '17.27Target', '1', '17.10Target', '2', '16.92Target', '3', '16.63Stoploss', '17.58']
# ['COIN', 'NAMESOLUSDT', '5-10xDirections', 'ShortFilled', 'fib', 'level', 'look', 'right', 'rejected', 'resistance.', '✌️Entry', '33.8-34.20✅Target', 'Profit', '1', '33.42Target', 'Profit', '2', '32.27Target', 'Profit', '3', '32.10Target', 'Profit', '4', '31.90Target', 'Profit', '5', '31.70Target', 'Profit', '6', '30.96Target', 'Profit', '7', '30.5Target', 'profit', '8', '27.16Stop', 'loss', '34.76']
# ['AVAXUSDT', 'SHORT', 'Leverage', 'Cross', '50x', 'Entry', '17.27', 'Target', '1', '17.10', 'Target', '2', '16.92', 'Target', '3', '16.63', 'Stoploss', '17.58']
# ['AVAXUSDT', 'SHORT', 'Leverage', 'Cross', '50x', 'Entry', '17.27', 'Target', '1', '17.10', 'Target', '2', '16.92', 'Target', '3', '16.63', 'Stoploss', '17.58']
# ['BTC', 'dominance', '40', 'Total', 'Crypto', 'marketcap', '956', 'billion.Today', 'Important', 'three', 'important', 'fundamental', 'data', 'released', '1230', 'pm', 'GMT.US', 'Average', 'Hourly', 'EarningNon', 'Farm', 'Employment', 'Change', 'USA', 'Unemployment', 'RateNew', 'member', 'member', '1', 'year', 'trading', 'experience', 'NOT', 'trade', '11-12', 'pm', 'gmt.']
# ['We', 'Launching', 'Our', 'Vip', 'Crypto', 'Signals', 'group', '🌟3-5', 'Signals', 'Daily', '✅🔥Intraday', 'Scalping', 'Signals', 'Both📈Price', '💠45', '1Month', '💠75', '2Month', '💠98', '3MonthExact', 'Entry-Stoploss-Target', '✅Signals', 'Will', 'Sent', 'By', 'CryptoLogy', 'Signals', 'Team', '📈✅Message', 'MisterWhales', 'For', 'More', 'Details', 'Enrollment']
# ['Analysis', '-Bitcoin', 'started', 'downside', 'movement', 'trading', '20000.', 'For', 'Bullish', 'momentum', 'Bitcoin', 'need', 'give', 'Candle', 'closing', '2050019600', 'working', 'good', 'support', 'level', 'Bitcoin.If', 'Bitcoin', 'continues', 'move', 'expect', 'reversal', 'sign', 'support', 'level.']
# ['🟢', 'Long', 'RENUSDTEntry', '0.12750', '-0.12820Targets', '🎯', '0.12850🎯', '0.12878🎯', '0.12896🛑', 'Stop', '0.11974Leverage', '10x', 'isolated']
# ['AVAXUSDT', 'SHORT', 'Leverage', 'Cross', '50x', 'Entry', '17.27', 'Target', '1', '17.10', 'Target', '2', '16.92', 'Target', '3', '16.63', 'Stoploss', '17.58']
# ['🟢', 'Long', 'RENUSDT', 'Entry', '0.12750', '-0.12820', 'Targets', '🎯', '0.12850', '🎯', '0.12878', '🎯', '0.12896', '🛑', 'Stop', '0.11974', 'Leverage', '10x', 'isolated']
# ['ETCUSDT', 'LONGLEVERAGE', '10XENTRY', '27.389TARGETS', '27.737', '-', '28.350', '-', '29.512', '-', '31.503SL', '26.977']
# ['Enroll', 'Fast', '📌', 'Our', 'Team', 'Ready', 'Provide', 'Premium', 'Signals', '✅', 'You', 'Can', 'Even', 'Cover', 'Your', 'Fees', 'In', 'One', 'Day', '🔥', 'If', 'Follow', 'Everything', 'Properly']
# ['BinanceNEOUSDT', 'Take-Profit', 'target', '1', '✅Profit', '3.534', '📈Period', '20', 'Minutes', '⏰']
# ['COIN', 'NAME', 'XRPUSDT', 'Long', 'Leverage', '10x', 'Directions', 'Long', '🚀', 'Entry', '0.4936-0.4662✅', 'Target', 'Profit', '1', '0.4988', 'Target', 'Profit', '2', '0.5045', 'Target', 'Profit', '3', '0.5285', 'Target', 'Profit', '4', '0.5531', 'Stop', 'loss', '0.45']
# ['Analysis', '-', 'BTC', 'closed', 'daily', 'candle', 'red', '19530.', 'Opening', 'price', '19960', 'high', '20068', 'low', '19320.Support', '19000', 'resistance', '20000.', '19500', 'level', 'need', 'confirmation', 'become', 'resistance', 'support.', 'Trade', 'carefully', 'manage', 'risk', 'according', 'support', 'resistance', 'levels.', 'BTC', 'dominance', '39.6', 'total', 'marketcap', '946', 'billion.', 'US', 'Jobs', 'report', 'released', '3.5', 'figure', 'improvement', 'previous', 'figure', '3.7.', 'This', 'caused', 'appreciation', 'US', 'DXY', 'however', 'downfall', 'observed', 'risk', 'asset', 'Gold', 'XAU', 'Stocks', 'SP500', 'Crypto', 'market.']
# ['HNTUSDT', '4H', 'TFHNT', 'broken', 'weekly', 'support', 'consolidating', 'equal', 'lows.', 'If', 'HNT', 'broke', 'trendline', '0.618golden', 'ratio', 'zone', 'Then', 'movement', 'downward', 'till', 'potential', 'reversal', 'zone', '0.7860.886FIB', 'level.']
# ['For', 'bitcoin', 'could', 'play', 'were', 'going', 'next.', 'Waiting', 'confirmation']
# ['GMTUSDT', 'LONGLeverage', 'Cross', '10xEntry', '0.5840-0.5400Target', '1', '0.6000Target', '2', '0.6136Target', '3', '0.6374Target', '4', '0.7430Stoploss', '0.5104']
# ['We', 'Launching', 'Our', 'Vip', 'Crypto', 'Signals', 'group', '🌟3-5', 'Signals', 'Daily', '✅🔥Intraday', 'Scalping', 'Signals', 'Both📈Price', '💠45', '1Month', '💠75', '2Month', '💠98', '3MonthExact', 'Entry-Stoploss-Target', '✅Signals', 'Will', 'Sent', 'By', 'CryptoLogy', 'Signals', 'Team', '📈✅Message', 'MisterWhales', 'For', 'More', 'Details', 'Enrollment']
# ['GMTUSDT', 'LONG', 'Leverage', 'Cross', '10x', 'Entry', '0.5840-0.5400', 'Target', '1', '0.6000', 'Target', '2', '0.6136', 'Target', '3', '0.6374', 'Target', '4', '0.7430', 'Stoploss', '0.5104']
# ['AnalysisMarket', 'rise', 'total', 'market', 'capitalization', 'cryptocurrencies', 'increasing', '2.79', '944.24', 'billion.BTC', 'broke', '19500', 'resistance', 'another', 'high', 'buying', 'volume', 'got', 'resistance', 'close', '20000.', 'BTC', 'current', 'support', '19500', 'resistance', '20000.', 'Manage', 'risk', 'strictly', 'according', 'support', 'resistance.']
# ['DOTUSDT', 'SHORTLeverage', 'Cross', '50xEntry', '6.125Target', '1', '6.039Target', '2', '5.984Target', '3', '5.892Stoploss', '6.241']
# ['DOTUSDT', 'SHORT', 'Leverage', 'Cross', '50x', 'Entry', '6.125', 'Target', '1', '6.039', 'Target', '2', '5.984', 'Target', '3', '5.892', 'Stoploss', '6.241']
# ['We', 'Provide', 'Scalping', 'Signals', 'From', 'Tomorrow', 'Which', 'Will', 'Highly', 'Accurate', 'Only', 'In', 'VIP', 'group', 'For', 'Regular', 'Earning', '🔥✅Make', 'Sure', 'Enroll', 'Today', '🔥']
# ['PEOPLEUSDT', 'LONG', '20X', 'ENTRY', '0.01760T1', '0.01801T2', '0.01833T3', '0.01855T4', '0.01878T5', '0.01905Stop', 'loss', '0.01700']
# ['PEOPLEUSDT', 'LONG', '20X', 'ENTRY', '0.01760', 'T1', '0.01801', 'T2', '0.01833', 'T3', '0.01855', 'T4', '0.01878', 'T5', '0.01905', 'Stop', 'loss', '0.01700']
# ['We', 'Launching', 'Our', 'Vip', 'Crypto', 'Signals', 'group', '🌟3-5', 'Signals', 'Daily', '✅🔥Intraday', 'Scalping', 'Signals', 'Both📈Price', '💠45', '1Month', '💠75', '2Month', '💠98', '3MonthExact', 'Entry-Stoploss-Target', '✅Signals', 'Will', 'Sent', 'By', 'CryptoLogy', 'Signals', 'Team', '📈✅Message', 'MisterWhales', 'For', 'More', 'Details', 'Enrollment']
# ['💠', 'UNIBTC', '-', 'Buy', 'signal', '💠Current', 'Price', '0.00032980', 'BinanceSuggested', 'Targets', '🎯T1', '0.00033310T2', '0.00033640T3', '0.00033969T4', '0.00034629Vol', '24h', '62.24074188STOP', '⛔', '0.00031991SCALPING', 'UNI']
# ['💠', 'UNIBTC', '-', 'Buy', 'signal', '💠', 'Current', 'Price', '0.00032980', 'Binance', 'Suggested', 'Targets', '🎯', 'T1', '0.00033310', 'T2', '0.00033640', 'T3', '0.00033969', 'T4', '0.00034629', 'Vol', '24h', '62.24074188', 'STOP', '⛔', '0.00031991', 'SCALPING', 'UNI']
# ['Binance', 'Futures', 'ByBit', 'USDTDOGEUSDT', 'All', 'take-profit', 'target', 'achieved', '😎Profit', '90.9091', '📈Period', '15', 'Minutes', '⏰']
# ['VIP', 'Members', 'Are', 'Rocking', 'With', 'Futures', 'Signals', 'For', 'Big', 'Profits', '✅🤩Message', 'MisterWhales', 'Enroll', 'Fast', '💨']
# ['Special', 'Sale', '😍', 'On', 'CryptoLogy', 'Vip', '👑Get', '3', 'Month', 'Subscriptions', 'In', '50', '✅For', 'First', '10', 'people', '🤲🔥Message', 'MisterWhales', 'Fast']
# ['The', 'CryptoLogy', '💎', '•', 'Signals', '•', 'Alerts', '🔔', 'pinned', '«Special', 'Sale', '😍', 'On', 'CryptoLogy', 'Vip', '👑', 'Get', '3', 'Month', 'Subscriptions', 'In', '50', '✅', 'For', 'First', '10', 'people', '🤲🔥', 'Message', 'MisterWhales', 'Fast»']
# ['Special', 'Sale', '😍', 'On', 'CryptoLogy', 'Vip', '👑', 'Get', '3', 'Month', 'Subscriptions', 'In', '50', '✅', 'For', 'First', '10', 'people', '🤲🔥', 'Message', 'MisterWhales', 'Fast']
# ['💠', 'DYDXBTC', '-', 'Buy', 'signal', '💠Current', 'Price', '0.00010881', 'BinanceSuggested', 'Targets', '🎯T1', '0.00010990T2', '0.00011099T3', '0.00011207T4', '0.00011425Vol', '24h', '315.44226138STOP', '⛔', '0.00010555SCALPING', 'DYDX']
# ['💠', 'DYDXBTC', '-', 'Buy', 'signal', '💠', 'Current', 'Price', '0.00010881', 'Binance', 'Suggested', 'Targets', '🎯', 'T1', '0.00010990', 'T2', '0.00011099', 'T3', '0.00011207', 'T4', '0.00011425', 'Vol', '24h', '315.44226138', 'STOP', '⛔', '0.00010555', 'SCALPING', 'DYDX']
# ['Mega', 'Profit', '✅\U0001fae3', 'DYDX', '🤤🤤🤤🤤🤤']
# ['Join', 'CryptoLogy', 'VIP', '👑', 'Check', 'Out', 'Below', 'For', 'More', 'Details', '👇httpsforms.gleSSSpbJvPL3Mxyc626CryptoLogy', 'VIP', 'Only', 'For', 'Profits', '✅']
# ['FREE', 'SIGNAL💠', 'ZECBTC', '-', 'Buy', 'signal', '💠Current', 'Price', '0.002426', 'BinanceSuggested', 'Targets', '🎯T1', '0.00247450T2', '0.00249900T3', '0.00252350T4', '0.00257250Vol', '24h', '66.62839425STOP', '⛔', '0.00237650SCALPING', 'ZEC']
# ['TRX', 'USDTCall', 'type', '👉', 'futuresDirection', '👉', 'shortLeverage', '👉', '2xShort', 'zone0.0495TO0.0510Target0.0490✅0.0485✅0.0480✅0.0475✅0.057✅Stop', 'loss0.58🚫Disclaimer', '👉', 'Call', 'risky', 'market', 'conditions.We', 'take', 'resposiblity', 'gurantee', 'profit', 'loss', 'suffred.👆.', 'Crypto', 'subjected', 'market', 'risk👆trade', 'risk.freesignal']
# ['BTC', 'USDTCall', 'type', '👉', 'futuresDirection', '👉', 'shortShort', 'zone16500TO16800Target16400✅16300✅16200✅16160✅Stop', 'loss17600🚫Disclaimer', '👉', 'Call', 'risky', 'market', 'conditions.We', 'take', 'resposiblity', 'gurantee', 'profit', 'loss', 'suffred.👆.', 'Crypto', 'subjected', 'market', 'risk👆trade', 'risk.freesignal']
# ['MATIC', 'USDTCall', 'type', '👉', 'futuresDirection', '👉', 'shortShort', 'zone0.905TO0.930Target0.900✅0.890✅0.880✅0.870✅Stop', 'loss1.0🚫Disclaimer', '👉', 'Call', 'risky', 'market', 'conditions.We', 'take', 'resposiblity', 'gurantee', 'profit', 'loss', 'suffred.👆.', 'Crypto', 'subjected', 'market', 'risk👆trade', 'risk.freesignal']
# ['BNB', 'USDTCall', 'type', '👉', 'futuresDirection', '👉', 'shortShort', 'zone277TO280Target276✅275✅274✅273✅272✅271✅Stop', 'loss302🚫Disclaimer', '👉', 'Call', 'risky', 'market', 'conditions.We', 'take', 'resposiblity', 'gurantee', 'profit', 'loss', 'suffred.👆.', 'Crypto', 'subjected', 'market', 'risk👆trade', 'risk.freesignal']
# ['FTM', 'USDTCall', 'type', '👉', 'futuresDirection', '👉', 'shortShort', 'zone0.1755TO0.1780Target0.1750✅0.1740✅0.1730✅0.1720✅Stop', 'loss0.1900🚫Disclaimer', '👉', 'Call', 'risky', 'market', 'conditions.We', 'take', 'resposiblity', 'gurantee', 'profit', 'loss', 'suffred.👆.', 'Crypto', 'subjected', 'market', 'risk👆trade', 'risk.freesignals']
# ['REN', 'USDTCall', 'type', '👉', 'futuresDirection', '👉', 'shortShort', 'zone0.0781TO0.079Target0.078✅0.077✅0.076✅0.075✅Stop', 'loss0.088🚫Disclaimer', '👉', 'Call', 'risky', 'market', 'conditions.We', 'take', 'resposiblity', 'gurantee', 'profit', 'loss', 'suffred.👆.', 'Crypto', 'subjected', 'market', 'risk👆trade', 'risk.FreeSignal']
# ['CHZ', 'USDTCall', 'type', '👉', 'futuresDirection', '👉', 'shortShort', 'zone0.190TO0.200Target0.189✅0.188✅0.187✅0.186✅0.185✅0.184✅Stop', 'loss0.220🚫Disclaimer', '👉', 'Call', 'risky', 'market', 'conditions.We', 'take', 'resposiblity', 'gurantee', 'profit', 'loss', 'suffred.👆.', 'Crypto', 'subjected', 'market', 'risk👆trade', 'risk.']
# ['TRX', 'USDT', 'Call', 'type', '👉', 'future', 'Direction', '👉', 'short', 'Leverage', '👉', '2x', 'Short', 'zone', '0.0495', 'TO', '0.0510', 'Target', '0.0490✅', '0.0485✅', '0.0480✅', '0.0475✅', '0.057✅', 'Stop', 'loss', '0.58🚫', 'Disclaimer', '👉', 'Call', 'risky', 'market', 'conditions.We', 'take…']
# ['BNB', 'USDT', 'Call', 'type', '👉', 'future', 'Direction', '👉', 'short', 'Short', 'zone', '277', 'TO', '280', 'Target', '276✅', '275✅', '274✅', '273✅', '272✅', '271✅', 'Stop', 'loss', '302🚫', 'Disclaimer', '👉', 'Call', 'risky', 'market', 'conditions.We', 'take', 'resposiblity', 'gurantee', 'profit…']
# ['FTM', 'USDT', 'Call', 'type', '👉', 'future', 'Direction', '👉', 'short', 'Short', 'zone', '0.1755', 'TO', '0.1780', 'Target', '0.1750✅', '0.1740✅', '0.1730✅', '0.1720✅', 'Stop', 'loss', '0.1900🚫', 'Disclaimer', '👉', 'Call', 'risky', 'market', 'conditions.We', 'take', 'resposiblity', 'gurantee…']
# ['SOL', 'USDTCall', 'type', '👉', 'futuresDirection', '👉', 'shortShort', 'zone13.5TO14.5Target13.2✅13.0✅12.8✅12.5✅Stop', 'loss16🚫Disclaimer', '👉', 'Call', 'risky', 'market', 'conditions.We', 'take', 'resposiblity', 'gurantee', 'profit', 'loss', 'suffred.👆.', 'Crypto', 'subjected', 'market', 'risk👆trade', 'risk.']
# ['BTC', 'facing', 'resistsnce', '17100', '17500.👆', 'Price', 'saw', 'upward', 'spike', 'market', 'got', 'rejection', '17k', 'level✅.', 'For', 'good', 'upside', 'move', 'btc', 'need', 'breach', '17500', 'level', 'order', 'move', 'upside👆.', 'Local', 'support', 'area', '15900', '15500✅.', 'Volume', 'low', 'need', 'good', 'upside', 'volume', 'breakout']
# ['FILUSDTSignal', 'Type', 'Regular', 'LongLeverage', 'Isolated25XEntry', 'Targets', '𝟭', '4.495𝟮', '4.329Take', 'Profit', 'Targets', '1', '4.5312', '4.6013', '4.6594', '4.7095', '4.800Stop', 'Loss𝟭', '4.216']
# ['💠', 'UNIBTC', '-', 'Buy', 'signal', '💠Current', 'Price', '0.00036130', 'BinanceSuggested', 'Targets', '🎯T1', '0.00036491T2', '0.00036853T3', '0.00037214T4', '0.00037936Vol', '24h', '165.72076663STOP', '⛔', '0.00035046SCALPING', 'UNIFreeSignal']
# ['BNB', 'USDT', 'Call', 'type', '👉', 'future', 'Direction', '👉', 'short', 'Short', 'zone', '277', 'TO', '280', 'Target', '276✅', '275✅', '274✅', '273✅', '272✅', '271✅', 'Stop', 'loss', '302🚫', 'Disclaimer', '👉', 'Call', 'risky', 'market', 'conditions.We', 'take', 'resposiblity', 'gurantee', 'profit…']
# ['MATIC', 'USDT', 'Call', 'type', '👉', 'future', 'Direction', '👉', 'short', 'Short', 'zone', '0.905', 'TO', '0.930', 'Target', '0.900✅', '0.890✅', '0.880✅', '0.870✅', 'Stop', 'loss', '1.0🚫', 'Disclaimer', '👉', 'Call', 'risky', 'market', 'conditions.We', 'take', 'resposiblity', 'gurantee', 'profit…']
# ['REN', 'USDT', 'Call', 'type', '👉', 'future', 'Direction', '👉', 'short', 'Short', 'zone', '0.0781', 'TO', '0.079', 'Target', '0.078✅', '0.077✅', '0.076✅', '0.075✅', 'Stop', 'loss', '0.088🚫', 'Disclaimer', '👉', 'Call', 'risky', 'market', 'conditions.We', 'take', 'resposiblity', 'gurantee', 'of…']
# ['💎BUY', 'BANDUSDT', 'LONGEntry', 'Targets', '2.013', '1.950Take-Profit', 'Targets1', '2.0212', '2.0313', '2.0424', '2.0605', '2.0806', '2.1007', '2.1258', '2.155Leverage', 'Cross', '20xStop-Loss', '1.85']
# ['🟢', 'LongATAUSDTEntry', '0.1023', '-', '0.1032Targets', '1', '0.10272', '0.10493', '0.10704', '0.1091Stop', '957614']
# ['Binance', 'Futures', 'ByBit', 'USDTBANDUSDT', 'Take-Profit', 'target', '1', '✅Take-Profit', 'target', '2', '✅Take-Profit', 'target', '3', '✅Take-Profit', 'target', '4', '✅Profit', '25.3353', '📈Period', '4', 'Hours', '3', 'Minutes', '⏰']
# ['SOL', 'USDT', 'Call', 'type', '👉', 'future', 'Direction', '👉', 'short', 'Short', 'zone', '13.5', 'TO', '14.5', 'Target', '13.2✅', '13.0✅', '12.8✅', '12.5✅', 'Stop', 'loss', '16🚫', 'Disclaimer', '👉', 'Call', 'risky', 'market', 'conditions.We', 'take', 'resposiblity', 'gurantee', 'profit…']
# ['Alert', 'news❗️❗️❗️FTX', 'hacker', 'converted', '25000', 'ETH', 'worth', '30', 'million', 'Bitcoin', 'on-chain', 'data', 'reveals.😱🥶🚩']
# ['Binance', 'Pool', 'Officially', 'Launches', 'RavenCoin', 'RVN', 'Mining', 'Poolhttpswww.binance.comensupportannouncementb9aaee162b9c4d90b868fdc716625446']
# ['COTI', 'USDTCall', 'type', '👉', 'futuresDirection', '👉', 'shortShort', 'zone0.071TO0.072Target0.0705✅0.0710✅0.0695✅0.0690✅0.0685✅Stop', 'loss0.0755🚫Disclaimer', '👉', 'Call', 'risky', 'market', 'conditions.We', 'take', 'resposiblity', 'gurantee', 'profit', 'loss', 'suffred.👆.', 'Crypto', 'subjected', 'market', 'risk👆trade', 'risk.']
# ['COTI', 'USDT', 'Call', 'type', '👉', 'future', 'Direction', '👉', 'short', 'Short', 'zone', '0.071', 'TO', '0.072', 'Target', '0.0705✅', '0.0710✅', '0.0695✅', '0.0690✅', '0.0685✅', 'Stop', 'loss', '0.0755🚫', 'Disclaimer', '👉', 'Call', 'risky', 'market', 'conditions.We', 'take', 'resposiblity…']
# 0      ['📌', 'ODIN', 'PLATFORM', '-', 'For', 'trader'...
# 1      ['🚨🚨', 'AMAZING', 'NEWS', '🚨🚨✴️', 'Leading', '...
# 2      ['COIN', 'NAMEDOTUSDTDirections', 'Long🚀Entry'...
# 3      ['COIN', 'NAMEHBARUSDTDirections', 'Long🚀Entry...
# 4      ['COIN', 'NAMEADAUSDTDirections', 'Long🚀ADA', ...
#                              ...
# 96     ['SOL', 'USDT', 'Call', 'type', '👉', 'future',...
# 97     ['Alert', 'news❗️❗️❗️FTX', 'hacker', 'converte...
# 98     ['Binance', 'Pool', 'Officially', 'Launches', ...
# 99     ['COTI', 'USDTCall', 'type', '👉', 'futuresDire...
# 100    ['COTI', 'USDT', 'Call', 'type', '👉', 'future'...
# Name: Cleaned_text, Length: 101, dtype: object
