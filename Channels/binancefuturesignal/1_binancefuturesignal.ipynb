# %%
import pandas as pd
import re
from csv import writer

# %%
colnames=['Name','Date','Time', 'Text','Cleaned_text'] 
exchanges = ['BINANCE', 'BYBIT', 'FTX', 'HUOBI', 'KUCOIN', 'POLONIEX','KRAKEN']
df = pd.read_csv('./1_binancefuturesignal.csv',names = colnames,header=None)
print(df['Cleaned_text'][0])
print(df['Text'][0])
df.head()
# Out:
# ['🎯🎯Excellent', 'profit', 'RUNEUSDT', 'Premium', 'Members🚀🚀It', 'crossed', 'profit', 'target', 'made', 'good', '48', 'profit👁\u200d🗨Contact', 'futurechief', 'enter', 'Premium', 'Binance', 'FuturesFTXBybitKucoin', 'SPOT', 'Group', 'daily', 'gain']
# 🎯🎯Excellent profit on #RUNE/USDT for all Premium Members🚀🚀It crossed all the profit targets and made a very good 48% profit👁‍🗨Contact @futurechief to enter the Premium Binance Futures/FTX/Bybit/Kucoin & SPOT Group for daily gains
#                   Name        Date      Time  \
# 0  binancefuturesignal  2022-09-15  08:50:51
# 1  binancefuturesignal  2022-09-15  12:21:51
# 2  binancefuturesignal  2022-09-15  15:58:03
# 3  binancefuturesignal  2022-09-15  17:53:58
# 4  binancefuturesignal  2022-09-15  19:50:59
#
#                                                 Text  \
# 0  🎯🎯Excellent profit on #RUNE/USDT for all Premi...
# 1  Free SignalBuy #JASMY/USDT around 8480 - 8420L...
# 2  🚀 Storming profits in the Premium Group🎯🎯 #AR/...
# 3  🚀🚀Raining Profits in the Premium Group - Amazi...
# 4  🎯🎯 Non Stop Huge profit on Premium signal for ...
#
#                                         Cleaned_text
# 0  ['🎯🎯Excellent', 'profit', 'RUNEUSDT', 'Premium...
# 1  ['Free', 'SignalBuy', 'JASMYUSDT', 'around', '...
# 2  ['🚀', 'Storming', 'profit', 'Premium', 'Group🎯...
# 3  ['🚀🚀Raining', 'Profits', 'Premium', 'Group', '...
# 4  ['🎯🎯', 'Non', 'Stop', 'Huge', 'profit', 'Premi...

# %%
exchanges = 'Binance|kucoin|bitbuy'
conversion = 'usdt|usd|btc|eth'
exchangeregex = '|'.join(exchanges)
target = ('|').join(['1','2','3'])
# coins=''
def extractor(i):
  text = re.sub('[\',\[\]]', '', i)

  if(re.search('free signal|entry point',text,re.IGNORECASE) and re.search('target|targets',text,re.IGNORECASE)):    

    # coin_name=re.findall('({})'.format(coins),text,re.IGNORECASE)
    conversion_name = re.findall('\w+({})'.format(conversion),str(text),re.IGNORECASE)
    
    """exchange not used"""
    call_exchange = re.findall('\w+({})'.format(exchanges),text,re.IGNORECASE)
    
    call_type = re.findall('sell|buy',text,re.IGNORECASE)

    """duration not used that much"""
    call_duration = re.findall('long|short',text,re.IGNORECASE)
    """current not given, between is given"""
    # current_value=re.findall('')

    leverage = re.findall('leverage\s*-*\s*(\d.*x)',text,re.IGNORECASE)
    # if (not leverage): print(text)
    print(leverage)

    """some targets are not extracted although format is same """
    targets=re.findall(r'targets\s*(\d.\d*)\s*-*\s*(\d.\d*)\s*-*\s*(\d.\d*)\s*-*\s*(\d.\d*)',text,re.IGNORECASE)
    """ stop loss not used that much"""
    stop_loss = re.findall('stop\s*loss\s*-*\s*(\d.\d*)',text,re.IGNORECASE)
  return i
  
df['Cleaned_text'].apply(extractor)
# Out:
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x']
# []
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x']
# ['10x']
# ['10x 25x 50x 100x']
# ['10x']
# ['10x']
# ['10x']
# ['10x 25x 50x 100x']
# []
# ['10x 25x 50x 100x']
# ['10x']
# ['10x']
# ['10x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x']
# ['10x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x']
# ['10x']
# ['10x']
# ['10x']
# ['10x']
# ['10x']
# ['10x']
# ['10x']
# ['10x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x']
# ['10x 25x 50x']
# ['10x 25x 50x']
# ['10x 25x 50x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x']
# []
# ['10x 25x 50x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# []
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x']
# ['10x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# []
# ['10x 25x 50x 100x']
# []
# ['10x 25x 50x 100x']
# []
# ['10x']
# ['10x']
# ['10x']
# ['10x']
# ['10x 25x 50x']
# ['10x']
# ['10x']
# ['10x']
# ['10x 25x 50x 100x']
# ['10x']
# ['10x']
# ['10x']
# ['10x']
# ['10x']
# []
# []
# []
# ['10x']
# ['10x']
# ['10x']
# ['10x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x']
# []
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x']
# ['10x']
# ['10x 25x 50x 100x']
# ['10x']
# ['10x']
# ['10x']
# ['10x 25x 50x 100x']
# []
# ['10x 25x 50x 100x']
# ['10x']
# ['10x']
# ['10x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x']
# ['10x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x']
# ['10x']
# ['10x']
# ['10x']
# ['10x']
# ['10x']
# ['10x']
# ['10x']
# ['10x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x']
# ['10x 25x 50x']
# ['10x 25x 50x']
# ['10x 25x 50x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x']
# []
# ['10x 25x 50x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# []
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# ['10x']
# ['10x']
# ['10x 25x 50x 100x']
# ['10x 25x 50x 100x']
# []
# ['10x 25x 50x 100x']
# []
# ['10x 25x 50x 100x']
# []
# ['10x']
# ['10x']
# ['10x']
# ['10x']
# ['10x 25x 50x']
# ['10x']
# ['10x']
# ['10x']
# ['10x 25x 50x 100x']
# ['10x']
# ['10x']
# ['10x']
# ['10x']
# ['10x']
# []
# []
# []
# ['10x']
# ['10x']
# ['10x']
# ['10x']
# 0       ['🎯🎯Excellent', 'profit', 'RUNEUSDT', 'Premium...
# 1       ['Free', 'SignalBuy', 'JASMYUSDT', 'around', '...
# 2       ['🚀', 'Storming', 'profit', 'Premium', 'Group🎯...
# 3       ['🚀🚀Raining', 'Profits', 'Premium', 'Group', '...
# 4       ['🎯🎯', 'Non', 'Stop', 'Huge', 'profit', 'Premi...
#                               ...
# 1600    ['🎯🎯Excellent', 'profit', 'MASKUSDT', 'Premium...
# 1601    ['🚀🚀Raining', 'Profits', 'Premium', 'Group', '...
# 1602    ['Free', 'SignalBuy', 'IOTAUSDT', 'around', '2...
# 1603    ['🚀🚀', 'Another', 'massive', 'profit', 'made',...
# 1604    ['👆👆As', 'see', 'great', 'way', 'inform', 'Pre...
# Name: Cleaned_text, Length: 1605, dtype: object
