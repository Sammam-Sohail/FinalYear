# %%
import pandas as pd
import re
from csv import writer

# %%
colnames=['Name','Date','Time', 'Text','Cleaned_text'] 
exchanges = ['BINANCE', 'BYBIT', 'FTX', 'HUOBI', 'KUCOIN', 'POLONIEX','KRAKEN']
df = pd.read_csv('./1_CryptoClassicsVIP.csv',names = colnames,header=None)
print(df['Cleaned_text'][0])
print(df['Text'][0])
df.head()
# Out:
# ['FLMUSDT', 'Trade', 'Type', 'long', 'position', 'Entry', 'zone', '0.1110', '-', '0.1145', 'Size', '3', 'Target', '1', '0.1230', '2', '0.1322', '3', '0.1413', 'Stop', '0.1049']
# #FLMUSDT  Trade Type: long position  Entry zone 0.1110 - 0.1145  Size: 3%   Target: 1) 0.1230 2) 0.1322 3) 0.1413  Stop 0.1049
#                 Name        Date      Time  \
# 0  CryptoClassicsVIP  2022-09-15  02:21:14
# 1  CryptoClassicsVIP  2022-09-15  14:04:13
# 2  CryptoClassicsVIP  2022-09-16  14:30:31
# 3  CryptoClassicsVIP  2022-09-18  21:08:02
# 4  CryptoClassicsVIP  2022-09-18  21:23:48
#
#                                                 Text  \
# 0  #FLMUSDT  Trade Type: long position  Entry zon...
# 1             The Ethereum Merge is completed — link
# 2  White House Releases Bitcoin, Crypto Regulator...
# 3  #DASHUSDT  Trade Type: long position  Entry zo...
# 4  #UNIUSDT  Trade Type: long position  Entry zon...
#
#                                         Cleaned_text
# 0  ['FLMUSDT', 'Trade', 'Type', 'long', 'position...
# 1  ['The', 'Ethereum', 'Merge', 'completed', '—',...
# 2  ['White', 'House', 'Releases', 'Bitcoin', 'Cry...
# 3  ['DASHUSDT', 'Trade', 'Type', 'long', 'positio...
# 4  ['UNIUSDT', 'Trade', 'Type', 'long', 'position...

# %%
exchanges = 'Binance|kucoin|bitbuy'
conversion = 'usdt|usd|btc|eth'
exchangeregex = '|'.join(exchanges)
target = ('|').join(['1','2','3'])
# coins=''
def extractor(i):
  text = re.sub('[\',\[\]]', '', i)

  if(re.search('\w+({})'.format(conversion),text,re.IGNORECASE) and re.search('target',text,re.IGNORECASE)):    

    coin_name=re.findall('(\w+)(?:usdt|usd|btc|eth)',text,re.IGNORECASE)

    conversion_name = re.findall('\w+({})'.format(conversion),str(text),re.IGNORECASE)

    """exchange not used"""
    call_exchange = re.findall('\w+({})'.format(exchanges),text,re.IGNORECASE)

    """"call type not used"""
    call_type = re.findall('sell|buy',text,re.IGNORECASE)

    call_duration = re.findall('long|short',text,re.IGNORECASE)

    """current not given around is given"""
    # current_value=re.findall('')
    
    """"leverage not used"""
    leverage = re.findall('[ ]*[-]*[ ]*(\d+)x',text,re.IGNORECASE)

    # targets = re.findall("(\d*[.]?\d*)[ ]?(-)?[ ]?(\d*[.]?\d*)[ ]?-[ ]?(\d*[.]?\d*)[ ]?-[ ]?(\d*[.]?\d*)[ ]?-[ ]?(\d*[.]?\d*)",text,re.IGNORECASE)
    """some targets are not extracted although format is same """
    T=dict()
    targets=re.findall(r'target\s*[0-9]\s*(\d.\d*)\s*[0-9]\s*(\d.\d*)\s*[0-9]\s*(\d.\d*)',text,re.IGNORECASE)

    if(targets):
      T['T1']=targets[0][0]
      T['T2']=targets[0][1]
      T['T3']=targets[0][2]

    stop_loss = re.findall('stop\s*(\d.\d*)',text,re.IGNORECASE)
    print(stop_loss)

    with open('./3_CryptoClassicsVIP.csv', 'a',newline='') as f_object:
      writer_object = writer(f_object)
      ls = [coin_name,conversion_name,leverage,call_exchange,call_type,call_duration,T,stop_loss]
      writer_object.writerow(ls)
      f_object.close()
  return i
  
df['Cleaned_text'].apply(extractor)
# Out:
# ['0.1049']
# ['42']
# ['5.44']
# ['0.434']
# ['0.599']
# ['0.599']
# ['1.335']
# ['0.599']
# ['45']
# ['0.256']
# ['5.97']
# ['1.06']
# ['1.06']
# ['0.27']
# ['1.06']
# ['0.599']
# ['37']
# ['37']
# ['0.699']
# ['0.699']
# ['3.52']
# ['1.54']
# ['1.54']
# ['1.06']
# ['1.54']
# ['106']
# ['106']
# ['37']
# ['256']
# ['256']
# ['0.03399']
# ['0.03399']
# ['0.999']
# ['0.999']
# ['0.00346']
# ['0.00346']
# ['0.399']
# ['0.00346']
# ['0.999']
# ['1.06']
# ['1.54']
# ['0.03399']
# ['4.99']
# ['37']
# ['106']
# ['0.699']
# ['0.00346']
# ['0.00325']
# ['0.85']
# ['0.999']
# ['256']
# ['256']
# ['0.999']
# ['43']
# ['3.52']
# ['0.27']
# ['256']
# 0     ['FLMUSDT', 'Trade', 'Type', 'long', 'position...
# 1     ['The', 'Ethereum', 'Merge', 'completed', '—',...
# 2     ['White', 'House', 'Releases', 'Bitcoin', 'Cry...
# 3     ['DASHUSDT', 'Trade', 'Type', 'long', 'positio...
# 4     ['UNIUSDT', 'Trade', 'Type', 'long', 'position...
#                             ...
# 71    ['DYDXUSDT', 'Trade', 'Type', 'long', 'positio...
# 72    ['LTCUSDT', 'Trade', 'Type', 'long', 'position...
# 73    ['CAKEUSDT', 'Trade', 'Type', 'long', 'positio...
# 74    ['ALGOUSDT', 'Trade', 'Type', 'long', 'positio...
# 75    ['BNBUSDT', 'Trade', 'Type', 'long', 'position...
# Name: Cleaned_text, Length: 76, dtype: object
