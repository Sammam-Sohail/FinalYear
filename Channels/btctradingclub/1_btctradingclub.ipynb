# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import re

# %%
colnames=['Name','Date','Time', 'Text','Cleaned_text'] 
exchanges = ['BINANCE', 'BYBIT', 'FTX', 'HUOBI', 'KUCOIN', 'POLONIEX','KRAKEN']
df = pd.read_csv('/content/gdrive/MyDrive/FinalYear/Models/s/Channels/btctradingclub/1_btctradingclub.csv',names = colnames,header=None)
print(df['Cleaned_text'][0])
print(df['Text'][0])
df.head()
# Out:
# ['✅Steady', 'Profit', '-', 'POLS', 'move', 'complete', '2nd', 'Profit', 'Target', 'Premium', 'member', '8', 'Profit👁\u200d🗨Contact', 'primemod', 'enter', 'Premium', 'Group', 'high', 'quality', 'signal', 'Spot', 'Futures', 'Market']
# ✅Steady Profit - #POLS moves further to complete the 2nd Profit Target for Premium members with 8% Profit👁‍🗨Contact @primemod to enter the Premium Group for high quality signals on Spot & Futures Market
#              Name        Date      Time  \
# 0  btctradingclub  2022-09-15  08:55:00
# 1  btctradingclub  2022-09-15  14:05:13
# 2  btctradingclub  2022-09-16  08:29:38
# 3  btctradingclub  2022-09-16  10:44:34
# 4  btctradingclub  2022-09-16  12:32:50
#
#                                                 Text  \
# 0  ✅Steady Profit - #POLS moves further to comple...
# 1  🚀🚀 6% Profit on #FORTH for our Premium Members...
# 2  ✅✅#ORN has completed the 3rd Profit Target on ...
# 3  Free SignalBuy #C98/USDT around 4020 - 4010Lev...
# 4  ✅✅✅40% Profit on #BAL/USDT for our Premium Mem...
#
#                                         Cleaned_text
# 0  ['✅Steady', 'Profit', '-', 'POLS', 'move', 'co...
# 1  ['🚀🚀', '6', 'Profit', 'FORTH', 'Premium', 'Mem...
# 2  ['✅✅ORN', 'completed', '3rd', 'Profit', 'Targe...
# 3  ['Free', 'SignalBuy', 'C98USDT', 'around', '40...
# 4  ['✅✅✅40', 'Profit', 'BALUSDT', 'Premium', 'Mem...

# %%
exchanges = 'Binance|kucoin|bitbuy'
conversion = 'usdt|usd|btc|eth'
exchangeregex = '|'.join(exchanges)
target = ('|').join(['1','2','3'])
# coins=''
def extractor(i):
  text = re.sub('[\',\[\]]', '', i)

  if(re.search('free\s*signal',text,re.IGNORECASE) and re.search('target|targets',text,re.IGNORECASE)):    

    # coin_name=re.findall('({})'.format(coins),text,re.IGNORECASE)
    conversion_name = re.findall('\w+({})'.format(conversion),str(text),re.IGNORECASE)
    
    """exchange not used"""
    call_exchange = re.findall('\w+({})'.format(exchanges),text,re.IGNORECASE)

    call_type = re.findall('sell|buy',text,re.IGNORECASE)

    """duration not used that much"""
    call_duration = re.findall('long|short',text,re.IGNORECASE)

    """current not given around is given"""
    # current_value=re.findall('')
    
    # targets = re.findall("(\d*[.]?\d*)[ ]?(-)?[ ]?(\d*[.]?\d*)[ ]?-[ ]?(\d*[.]?\d*)[ ]?-[ ]?(\d*[.]?\d*)[ ]?-[ ]?(\d*[.]?\d*)",text,re.IGNORECASE)
    """some targets are not extracted although format is same """
    targets=re.findall(r'targets\s*(\d.\d*)\s*-*\s*(\d.\d*)\s*-*\s*(\d.\d*)\s*-*\s*(\d.\d*)',text,re.IGNORECASE)
    # if(not targets): print(text)

    """ stop loss used rarely also without value"""
    stop_loss = re.findall('stop\s*loss\s*-*\s*(\d.\d*)',text,re.IGNORECASE)
  return i
  
df['Cleaned_text'].apply(extractor)
# Out:
# 0      ['✅Steady', 'Profit', '-', 'POLS', 'move', 'co...
# 1      ['🚀🚀', '6', 'Profit', 'FORTH', 'Premium', 'Mem...
# 2      ['✅✅ORN', 'completed', '3rd', 'Profit', 'Targe...
# 3      ['Free', 'SignalBuy', 'C98USDT', 'around', '40...
# 4      ['✅✅✅40', 'Profit', 'BALUSDT', 'Premium', 'Mem...
#                              ...
# 405    ['Free', 'SignalBuy', 'MKRUSDT', 'around', '67...
# 406    ['Free', 'Signal', 'Buy', 'MKRUSDT', 'around',...
# 407    ['✅✅STPT', 'completed', '3rd', 'Profit', 'Targ...
# 408    ['🚀🚀20', 'Profit', 'GMX', 'Premium', 'Members'...
# 409    ['Free', 'Signal', 'SHORTSELL', 'SFPUSDT', 'ar...
# Name: Cleaned_text, Length: 410, dtype: object
