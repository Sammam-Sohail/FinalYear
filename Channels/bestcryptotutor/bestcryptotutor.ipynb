# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import re

# %%
colnames=['Name','Date','Time', 'Text','Cleaned_text'] 
df = pd.read_csv('/content/gdrive/MyDrive/FinalYear/Models/s/Channels/bestcryptotutor/1_bestcryptotutor.csv',header=None,names = colnames)
df
# Out:
#                 Name        Date      Time  \
# 0    bestcryptotutor  2022-09-15  09:28:14
# 1    bestcryptotutor  2022-09-15  10:41:07
# 2    bestcryptotutor  2022-09-15  10:50:52
# 3    bestcryptotutor  2022-09-15  13:11:43
# 4    bestcryptotutor  2022-09-15  13:12:07
# ..               ...         ...       ...
# 190  bestcryptotutor  2022-11-19  06:35:21
# 191  bestcryptotutor  2022-11-19  10:49:24
# 192  bestcryptotutor  2022-11-19  15:54:57
# 193  bestcryptotutor  2022-11-19  19:34:03
# 194  bestcryptotutor  2022-11-20  07:06:42
#
#                                                   Text  \
# 0    Signal Type🚦FutureExchange♻️ BinanceCoin ➡️(CO...
# 1    Signal Type🚦Future Exchange♻️ Binance Coin ➡️(...
# 2    Signal Type🚦Future Exchange♻️ Binance Coin ➡️(...
# 3    Signal Type🚦Future Exchange♻️ Binance Coin ➡️(...
# 4                              COMP  Dumping Hard🔥🔥🔥🔥🔥
# ..                                                 ...
# 190  Signal Type🚦Future/Spot Exchange♻️ Binance Coi...
# 191  Signal Type🚦Future/SpotExchange♻️ BinanceCoin ...
# 192  Signal Type🚦Future/Spot Exchange♻️ Binance Coi...
# 193  Signal Type🚦Future/Spot Exchange♻️ Binance Coi...
# 194  Signal Type🚦Future/Spot Exchange♻️ Binance Coi...
#
#                                           Cleaned_text
# 0    ['Signal', 'Type🚦FutureExchange♻️', 'BinanceCo...
# 1    ['Signal', 'Type🚦Future', 'Exchange♻️', 'Binan...
# 2    ['Signal', 'Type🚦Future', 'Exchange♻️', 'Binan...
# 3    ['Signal', 'Type🚦Future', 'Exchange♻️', 'Binan...
# 4                     ['COMP', 'Dumping', 'Hard🔥🔥🔥🔥🔥']
# ..                                                 ...
# 190  ['Signal', 'Type🚦FutureSpot', 'Exchange♻️', 'B...
# 191  ['Signal', 'Type🚦FutureSpotExchange♻️', 'Binan...
# 192  ['Signal', 'Type🚦FutureSpot', 'Exchange♻️', 'B...
# 193  ['Signal', 'Type🚦FutureSpot', 'Exchange♻️', 'B...
# 194  ['Signal', 'Type🚦FutureSpot', 'Exchange♻️', 'B...
#
# [195 rows x 5 columns]

# %%
exchanges = ['Binance']
suffixes = 'usdt|usd|btc|eth'
exchangeregex = '|'.join(exchanges)\


def extractor(i):
    text = re.sub('[\',\[\]✅🚫]', '', i)
    if(re.search('^Signal',text,re.IGNORECASE)):
        total_targets = list(set([str(i+1) for i in  range(len(list(set(re.findall('Target[ ]?(\d*)',text,re.IGNORECASE)))))]))
        target = ('|').join(total_targets)
        print(text)
        print(re.findall("Target ({})[ ]?[ ]?(\d*[.]?\d*)".format(target),text,re.IGNORECASE))
        
        
        # print(list(set(re.findall('Target[ ]?(\d*)',text,re.IGNORECASE))))
        # Targets = re.search("Target[ ]?2[ ]?(\d*[.]?\d*)[ ]?",text,re.IGNORECASE)
        # print(Targets)
    # print(text)
    # coin_name,call_type,Targets = [None]*3
    # try:
    #     coin_name = re.search("\w+({})".format(suffixes), str(text),re.IGNORECASE).group()
    #     try:
    #         call_type = re.search("Sell|Buy",text,re.IGNORECASE).group()
    #         try:
    #             Targets = re.search("(\d*[.]?\d*)[ ]?(-)?[ ]?(\d*[.]?\d*)[ ]?-[ ]?(\d*[.]?\d*)[ ]?-[ ]?(\d*[.]?\d*)[ ]?-[ ]?(\d*[.]?\d*)",text,re.IGNORECASE).group()
    #         except:
    #             Targets = None
    #     except:
    #         call_type = None 
    # except:
    #     coin_name = None
    # Targets = re.search("((\d*[.]?\d*)[ ]?(-)?[ ]?(\d*[.]?\d*)[ ]?-[ ]?(\d*[.]?\d*)[ ]?-[ ]?(\d*[.]?\d*))?",text,re.IGNORECASE).group()
    # print(Targets)
    # t1,t2,t3,t4= re.sub('\s?','',Targets).split('-')
    # print(t1,t2,t3,t4)
    # entry_type = None
    # stoploss,leverage = re.findall('[ ]?Stop loss[ ]?(\d*[.]?\d*)|[ ]?Leverage[ ]?(\d*)',str(text),re.IGNORECASE)
    # print(stoploss[0],leverage[1])
    # print(coin_name,call_type,entry_type,stoploss,leverage)
    return i
    
df['Cleaned_text'].apply(extractor)
# Out:
# [('1', '55.5'), ('2', '55.0'), ('3', '54.5'), ('4', '54.0'), ('5', '53.0'), ('6', '52.0'), ('7', '50.0'), ('8', '47.0'), ('1', '.')]
# [('1', '55.5'), ('2', '55.0'), ('3', '54.5'), ('4', '54.0'), ('5', '53.0'), ('6', '')]
# [('1', '55.5'), ('2', '55.0'), ('3', '54.5'), ('4', '54.0'), ('5', '53.0'), ('6', '')]
# [('1', '55.5'), ('2', '55.0'), ('3', '54.5'), ('4', '54.0'), ('5', '53.0'), ('6', '')]
# [('1', '2.73'), ('2', '2.75'), ('3', '2.77'), ('4', '2.80'), ('5', '2.85'), ('6', '2.90'), ('7', '3.00'), ('8', '3.20'), ('1', '.')]
# [('1', '1320'), ('2', '1330'), ('3', '1350'), ('4', '1380'), ('5', '1400'), ('6', '1450'), ('7', '1500'), ('8', '1600'), ('1', '.')]
# [('1', '261'), ('2', '263'), ('3', '265'), ('4', '268'), ('5', '270'), ('6', '275'), ('7', '280'), ('8', '290'), ('9', '300'), ('1', '.')]
# [('1', '261'), ('2', '263'), ('3', '265'), ('4', '268')]
# [('1', '261'), ('2', '263'), ('3', '265'), ('4', '268')]
# [('1', '261'), ('2', '263'), ('3', '265'), ('4', '268')]
# [('1', '261'), ('2', '263'), ('3', '265'), ('4', '268')]
# [('1', '0.245'), ('2', '0.240'), ('3', '0.235'), ('4', '0.230'), ('5', '0.225'), ('6', '0.220'), ('7', '0.200'), ('8', '0.180'), ('1', '.')]
# [('1', '0.245'), ('2', '0.240'), ('3', '0.235'), ('4', '0.230'), ('5', '0.225')]
# [('1', '0.245'), ('2', '0.240'), ('3', '0.235'), ('4', '0.230'), ('5', '0.225')]
# [('1', '0.245'), ('2', '0.240'), ('3', '0.235'), ('4', '0.230'), ('5', '0.225')]
# [('1', '0.245'), ('2', '0.240'), ('3', '0.235'), ('4', '0.230'), ('5', '0.225')]
# [('1', '1.06'), ('2', '1.07'), ('3', '1.08'), ('4', '1.09'), ('5', '1.10'), ('6', '1.12'), ('7', '1.15'), ('8', '1.20'), ('9', '1.25'), ('1', '.')]
# [('1', '1.06'), ('2', '1.07'), ('3', '1.08'), ('4', '1.09'), ('5', '1.10')]
# [('1', '0.76'), ('2', '0.77'), ('3', '0.78'), ('4', '0.79'), ('5', '0.80'), ('6', '0.82')]
# [('1', '0.630'), ('2', '0.625'), ('3', '0.620'), ('4', '0.615'), ('5', '0.610'), ('6', '0.600'), ('7', '0.580'), ('8', '0.550'), ('1', '.')]
# [('1', '0.00755'), ('2', '0.00765'), ('3', '0.00775'), ('4', '0.00785'), ('5', '0.00800'), ('6', '0.00850'), ('7', '0.00900'), ('8', '0.01000'), ('1', '.')]
# [('1', '0.00755'), ('2', '0.00765'), ('3', '0.00775'), ('4', '0.00785')]
# [('1', '0.00755'), ('2', '0.00765'), ('3', '0.00775'), ('4', '0.00785')]
# [('1', '1320'), ('2', '1310'), ('3', '1300'), ('4', '1290'), ('5', '1280'), ('6', '1260'), ('7', '1240'), ('1', '.')]
# [('1', '0.630'), ('2', '0.625'), ('3', '0.620'), ('4', '0.615'), ('5', '0.610')]
# [('1', '0.630'), ('2', '0.625'), ('3', '0.620'), ('4', '0.615'), ('5', '0.610')]
# [('1', '30.5'), ('2', '31.0'), ('3', '31.5'), ('4', '32.0'), ('5', '32.5'), ('6', '33.0'), ('7', '35.0'), ('1', '.')]
# [('1', '0.630'), ('2', '0.625'), ('3', '0.620'), ('4', '0.615'), ('5', '0.610')]
# [('1', '1.51'), ('2', '1.52'), ('3', '1.53'), ('4', '1.54'), ('5', '1.55'), ('6', '1.60'), ('7', '1.65'), ('8', '1.70'), ('9', '1.80'), ('1', '.')]
# [('1', '1.51'), ('2', '1.52'), ('3', '1.53'), ('4', '1.54'), ('5', '1.55'), ('6', '')]
# [('1', '1.51'), ('2', '1.52'), ('3', '1.53'), ('4', '1.54'), ('5', '1.55'), ('6', '')]
# [('1', '1.51'), ('2', '1.52'), ('3', '1.53'), ('4', '1.54'), ('5', '1.55'), ('6', '')]
# [('1', '1305'), ('2', '1300'), ('3', '1290'), ('4', '1280'), ('5', '1270'), ('6', '1260'), ('7', '1240'), ('8', '1220'), ('1', '.')]
# [('1', '8.42'), ('2', '8.37'), ('3', '8.34'), ('4', '8.28'), ('5', '8.22'), ('6', '8.17'), ('7', '8.00'), ('1', '.')]
# [('1', '8.42'), ('2', '8.37'), ('3', '8.34'), ('4', '8.28'), ('5', '8.22')]
# [('1', '8.42'), ('2', '8.37'), ('3', '8.34'), ('4', '8.28'), ('5', '8.22')]
# [('1', '8.42'), ('2', '8.37'), ('3', '8.34'), ('4', '8.28'), ('5', '8.22')]
# [('1', '8.42'), ('2', '8.37'), ('3', '8.34'), ('4', '8.28'), ('5', '8.22')]
# [('1', '0.0265'), ('2', '0.0270'), ('3', '0.0275'), ('4', '0.0280'), ('5', '0.0290'), ('6', '0.0300'), ('7', '0.0330'), ('8', '0.0350'), ('9', '0.0380'), ('1', '.')]
# [('1', '0.0265'), ('2', '0.0270'), ('3', '0.0275'), ('4', '0.0280'), ('5', '')]
# [('1', '0.0265'), ('2', '0.0270'), ('3', '0.0275'), ('4', '0.0280'), ('5', '')]
# [('1', '0.0350'), ('2', '0.0355'), ('3', '0.0360'), ('4', '0.0365'), ('5', '0.0370'), ('6', '0.0400'), ('7', '0.0450'), ('8', '0.0480'), ('1', '.')]
# [('1', '0.0350'), ('2', '0.0355'), ('3', '0.0360'), ('4', '0.0365'), ('5', '')]
# [('1', '0.0265'), ('2', '0.0270'), ('3', '0.0275'), ('4', '0.0280'), ('5', '')]
# [('1', '275'), ('2', '277'), ('3', '280'), ('4', '282')]
# [('1', '52.5'), ('2', '53.0'), ('3', '53.5'), ('4', '54.0'), ('5', '54.5'), ('6', '')]
# [('1', '0.0350'), ('2', '0.0355'), ('3', '0.0360'), ('4', '0.0365'), ('5', '')]
# [('1', '0.0350'), ('2', '0.0355'), ('3', '0.0360'), ('4', '0.0365'), ('5', '')]
# [('1', '0.0265'), ('2', '0.0270'), ('3', '0.0275'), ('4', '0.0280'), ('5', '')]
# [('1', '0.079'), ('2', '0.078'), ('3', '0.077'), ('4', '0.076'), ('5', '0.075'), ('6', '0.073'), ('7', '0.070'), ('8', '0.065'), ('1', '.')]
# [('1', '0.079'), ('2', '0.078'), ('3', '0.077'), ('4', '0.076'), ('5', '0.075')]
# [('1', '0.079'), ('2', '0.078'), ('3', '0.077'), ('4', '0.076'), ('5', '0.075')]
# [('1', '0.079'), ('2', '0.078'), ('3', '0.077'), ('4', '0.076'), ('5', '0.075')]
# [('1', '1.51'), ('2', '1.52'), ('3', '1.53'), ('4', '1.54'), ('5', '1.55'), ('6', '')]
# [('1', '275'), ('2', '277'), ('3', '280'), ('4', '282')]
# [('1', '275'), ('2', '277'), ('3', '280'), ('4', '282')]
# [('1', '1600'), ('2', '1580'), ('3', '1560'), ('4', '1540'), ('5', '1520'), ('6', '1500'), ('7', '1480'), ('8', '1450'), ('9', '1400'), ('1', '.')]
# [('1', '0.0350'), ('2', '0.0355'), ('3', '0.0360'), ('4', '0.0365'), ('5', '')]
# [('1', '0.0350'), ('2', '0.0355'), ('3', '0.0360'), ('4', '0.0365'), ('5', '')]
# [('1', '24.5'), ('2', '24.0'), ('3', '23.5'), ('4', '23.0'), ('5', '22.5'), ('6', '22.0'), ('7', '21.0'), ('8', '20.0'), ('1', '.')]
# [('1', '24.5'), ('2', '24.0'), ('3', '23.5'), ('4', '23.0'), ('5', '22.5'), ('6', '22.0')]
# [('1', '24.5'), ('2', '24.0'), ('3', '23.5'), ('4', '23.0'), ('5', '22.5'), ('6', '22.0')]
# [('1', '325'), ('2', '322'), ('3', '320'), ('4', '315'), ('5', '305'), ('6', '290'), ('7', '280'), ('8', '270'), ('1', '.')]
# [('1', '325'), ('2', '322'), ('3', '320'), ('4', '315'), ('5', '305'), ('6', '290')]
# [('1', '325'), ('2', '322'), ('3', '320'), ('4', '315'), ('5', '305'), ('6', '290')]
# [('1', '325'), ('2', '322'), ('3', '320'), ('4', '315'), ('5', '305'), ('6', '290')]
# [('1', '24.5'), ('2', '24.0'), ('3', '23.5'), ('4', '23.0'), ('5', '22.5'), ('6', '22.0')]
# [('1', '325'), ('2', '322'), ('3', '320'), ('4', '315'), ('5', '305'), ('6', '290')]
# [('1', '0.86'), ('2', '0.84'), ('3', '0.82'), ('4', '0.80'), ('5', '0.78'), ('6', '0.76'), ('7', '0.74'), ('8', '0.70'), ('9', '0.65'), ('1', '.')]
# [('1', '24.5'), ('2', '24.0'), ('3', '23.5'), ('4', '23.0'), ('5', '22.5'), ('6', '22.0')]
# [('1', '0.86'), ('2', '0.84'), ('3', '0.82'), ('4', '0.80'), ('5', '0.78')]
# [('1', '0.0265'), ('2', '0.0270'), ('3', '0.0275'), ('4', '0.0280'), ('5', '')]
# [('1', '13.8'), ('2', '14.0'), ('3', '14.5'), ('4', '15.0'), ('5', '15.5'), ('6', '16.0'), ('7', '17.0'), ('8', '20.0'), ('1', '.')]
# [('1', '13.8'), ('2', '14.0'), ('3', '14.5'), ('4', '15.0'), ('5', '15.5')]
# [('1', '13.8'), ('2', '14.0'), ('3', '14.5'), ('4', '15.0'), ('5', '15.5')]
# [('1', '346'), ('2', '348'), ('3', '350'), ('4', '355'), ('5', '360'), ('6', '370'), ('7', '380'), ('8', '400'), ('9', '440'), ('1', '.')]
# [('1', '346'), ('2', '348'), ('3', '350'), ('4', '355')]
# [('1', '346'), ('2', '348'), ('3', '350'), ('4', '355')]
# [('1', '346'), ('2', '348'), ('3', '350'), ('4', '355')]
# [('1', '13.8'), ('2', '14.0'), ('3', '14.5'), ('4', '15.0'), ('5', '15.5')]
# [('1', '346'), ('2', '348'), ('3', '350'), ('4', '355')]
# [('1', '346'), ('2', '348'), ('3', '350'), ('4', '355')]
# [('1', '0.0265'), ('2', '0.0270'), ('3', '0.0275'), ('4', '0.0280'), ('5', '')]
# [('1', '0.45'), ('2', '0.47'), ('3', '0.50'), ('4', '0.55'), ('5', '0.60'), ('6', '0.70'), ('7', '0.80'), ('9', '1.20'), ('1', '0'), ('1', '.')]
# [('1', '13.8'), ('2', '14.0'), ('3', '14.5'), ('4', '15.0'), ('5', '15.5')]
# [('1', '346'), ('2', '348'), ('3', '350'), ('4', '355')]
# [('1', '11.5'), ('2', '11.0'), ('3', '10.5'), ('4', '10.0'), ('5', '9.0'), ('6', '8.0'), ('7', '7.0'), ('8', '6.0'), ('1', '.')]
# [('1', '11.5'), ('2', '11.0'), ('3', '10.5'), ('4', '10.0'), ('5', '9.0')]
# [('1', '11.5'), ('2', '11.0'), ('3', '10.5'), ('4', '10.0'), ('5', '9.0')]
# [('1', '11.5'), ('2', '11.0'), ('3', '10.5'), ('4', '10.0'), ('5', '9.0')]
# [('1', '11.5'), ('2', '11.0'), ('3', '10.5'), ('4', '10.0'), ('5', '9.0')]
# [('1', '17500'), ('2', '17300'), ('3', '17000'), ('4', '16800'), ('5', '16500'), ('6', '16200'), ('7', '16000'), ('8', '15500'), ('1', '.')]
# [('1', '1285'), ('2', '1295'), ('3', '1305'), ('4', '1320'), ('5', '1350'), ('6', '1400'), ('7', '1410'), ('8', '1420'), ('1', '.')]
# [('1', '59.5'), ('2', '60.0'), ('3', '60.5'), ('4', '61.0'), ('5', '61.5'), ('6', '62.0'), ('7', '63.0'), ('8', '65.0'), ('1', '.')]
# [('1', '59.5'), ('2', '60.0'), ('3', '60.5'), ('4', '61.0'), ('5', '61.5'), ('6', '')]
# [('1', '0.93'), ('2', '0.92'), ('3', '0.91'), ('4', '0.90'), ('5', '0.88'), ('6', '0.85'), ('7', '0.83'), ('8', '0.80'), ('9', '0.70'), ('1', '.')]
# [('1', '0.93'), ('2', '0.92'), ('3', '0.91'), ('4', '')]
# [('1', '59.5'), ('2', '60.0'), ('3', '60.5'), ('4', '61.0'), ('5', '61.5'), ('6', '')]
# [('1', '0.93'), ('2', '0.92'), ('3', '0.91'), ('4', '')]
# [('1', '0.93'), ('2', '0.92'), ('3', '0.91'), ('4', '')]
# [('1', '0.93'), ('2', '0.92'), ('3', '0.91'), ('4', '')]
# [('1', '2.30'), ('2', '2.25'), ('3', '2.20'), ('4', '2.15'), ('5', '2.10'), ('6', '2.00'), ('7', '1.80'), ('1', '.')]
# [('1', '0.93'), ('2', '0.92'), ('3', '0.91'), ('4', '')]
# [('1', '2.30'), ('2', '2.25'), ('3', '2.20'), ('4', '2.15'), ('5', '2.10'), ('6', '2.00')]
# [('1', '2.30'), ('2', '2.25'), ('3', '2.20'), ('4', '2.15'), ('5', '2.10'), ('6', '2.00')]
# [('1', '5.80'), ('2', '5.70'), ('3', '5.50'), ('4', '5.30'), ('5', '5.10'), ('6', '4.80'), ('7', '4.50'), ('1', '.')]
# [('1', '5.80'), ('2', '5.70'), ('3', '5.50'), ('4', '5.30'), ('5', '5.10')]
# [('1', '2.30'), ('2', '2.25'), ('3', '2.20'), ('4', '2.15'), ('5', '2.10'), ('6', '2.00')]
# [('1', '5.80'), ('2', '5.70'), ('3', '5.50'), ('4', '5.30'), ('5', '5.10')]
# [('1', '2.30'), ('2', '2.25'), ('3', '2.20'), ('4', '2.15'), ('5', '2.10'), ('6', '2.00')]
# [('1', '59.5'), ('2', '60.0'), ('3', '60.5'), ('4', '61.0'), ('5', '61.5'), ('6', '')]
# [('1', '59.5'), ('2', '60.0'), ('3', '60.5'), ('4', '61.0'), ('5', '61.5'), ('6', '')]
# [('1', '1195'), ('2', '1185'), ('3', '1170'), ('4', '1150'), ('5', '1100'), ('6', '1050'), ('7', '1000'), ('1', '.')]
# [('1', '0.93'), ('2', '0.92'), ('3', '0.91'), ('4', '')]
# [('1', '0.60'), ('2', '0.61'), ('3', '0.62'), ('4', '0.63'), ('5', '0.64'), ('6', '0.65'), ('7', '0.70'), ('8', '0.80'), ('1', '.')]
# [('1', '0.60'), ('2', '0.61'), ('3', '0.62'), ('4', '0.63'), ('5', '0.64'), ('6', '')]
# [('1', '0.60'), ('2', '0.61'), ('3', '0.62'), ('4', '0.63'), ('5', '0.64'), ('6', '')]
# [('1', '0.60'), ('2', '0.61'), ('3', '0.62'), ('4', '0.63'), ('5', '0.64'), ('6', '')]
# 0      ['Signal', 'Type🚦FutureExchange♻️', 'BinanceCo...
# 1      ['Signal', 'Type🚦Future', 'Exchange♻️', 'Binan...
# 2      ['Signal', 'Type🚦Future', 'Exchange♻️', 'Binan...
# 3      ['Signal', 'Type🚦Future', 'Exchange♻️', 'Binan...
# 4                       ['COMP', 'Dumping', 'Hard🔥🔥🔥🔥🔥']
#                              ...
# 190    ['Signal', 'Type🚦FutureSpot', 'Exchange♻️', 'B...
# 191    ['Signal', 'Type🚦FutureSpotExchange♻️', 'Binan...
# 192    ['Signal', 'Type🚦FutureSpot', 'Exchange♻️', 'B...
# 193    ['Signal', 'Type🚦FutureSpot', 'Exchange♻️', 'B...
# 194    ['Signal', 'Type🚦FutureSpot', 'Exchange♻️', 'B...
# Name: Cleaned_text, Length: 195, dtype: object
