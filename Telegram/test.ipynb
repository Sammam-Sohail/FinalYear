# %%
import snscrape.modules.telegram as telegram
for x,tel in enumerate(telegram.TelegramChannelScraper("bestcryptotutor").get_items()):
    print(tel.content)
# Out:
# Signal Type🚦Future Exchange♻️ Binance Coin ➡️(BTC/USDT) Direction Short🛑 Leverage ♦️ Isolated 5x Margin💰Use 5% of your portfolio  Sell Above ❇️ 23400 DCA Till  ⚛️ 24000  Target 1 ✅ 23000 Target 2✅ 22700 Target 3✅ 22400 Target 4✅ 22000 Target 5✅ 21800 Target…
# Signal Type🚦SpotExchange♻️ BinanceCoin ➡️(GTC/USDT)Margin💰Use 5% of your portfolio Buy Below ❇️ 2.13DCA Till  ⚛️ 2.00Target 1 ✅ 2.20Target 2✅ 2.30Target 3✅ 2.40Target 4✅ 2.50Target 5✅ 2.60Target 6✅ 2.70Target 7✅ 2.80Targets 8✅ 3.00+STOPLOSS🚫 1.89 use 2-5x only*Note*‼️•Always Buy/sell coin in parts don't buy/sell in one shot.•Always book your profit on target 1.•Do your own risk management.•Always use Stoploss#Do at your own risk
# Signal Type🚦Future/Spot Exchange♻️ Binance Coin ➡️(ONE/USDT) Direction Long🟢 Leverage ♦️ Isolated 5x Margin💰Use 5% of your portfolio   Buy Below ❇️ 0.02174 DCA Till  ⚛️ 0.02100  Target 1 ✅ 0.02200 Target 2✅ 0.02230 Target 3✅ 0.02250 Target 4✅ 0.02280 Target…
# ...
